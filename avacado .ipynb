# %%
import pandas as pd
import numpy as np
df_avocado=pd.read_csv("avocado.csv")
df_avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
#checking null
df_avocado.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df_avocado.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#drop column index which has no impact on dataset
df_avocado.drop(columns=["Unnamed: 0"])
df_avocado=df_avocado.drop(columns=["Unnamed: 0"])

# %%
#checking number of rows and columns n dataset
df_avocado.shape
# Out:
# (18249, 13)

# %%
#checking null values using heatmap
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df_avocado.isnull())

# %%
#finding type of avocado sold yerwise
df_avocado.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %%
df_avocado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000

# %%
sns.barplot(x="year",y="AveragePrice",data=df_avocado)

# %%
#chexking skewness
df_avocado.skew
# Out:
# <bound method DataFrame.skew of              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]>

# %%
#ploting boxplot for each column to chek outliars
df_avocado.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,15))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Volume     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4046              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Small Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Large Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# year            AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# dtype: object

# %%
skew=('Total Volume','AveragePrice','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags')
for col in skew:
    if df_avocado.skew().loc[col]>0.55:
        df_avocado[col]=np.log1p(df_avocado[col])

# %%
#checking corelation matrix
df_avocado.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.592833 -0.556817 -0.457034 -0.518407
# Total Volume     -0.592833      1.000000  0.886538  0.908610  0.834274
# 4046             -0.556817      0.886538  1.000000  0.761893  0.747167
# 4225             -0.457034      0.908610  0.761893  1.000000  0.794104
# 4770             -0.518407      0.834274  0.747167  0.794104  1.000000
# Total Bags       -0.579452      0.934924  0.785653  0.790640  0.773176
# Small Bags       -0.496176      0.876670  0.741634  0.722492  0.747692
# Large Bags       -0.484128      0.671429  0.582992  0.614586  0.558938
# XLarge Bags      -0.385735      0.661647  0.585774  0.589352  0.643214
# year              0.092480      0.086274  0.011078  0.014321 -0.040618
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.579452   -0.496176   -0.484128    -0.385735  0.092480
# Total Volume    0.934924    0.876670    0.671429     0.661647  0.086274
# 4046            0.785653    0.741634    0.582992     0.585774  0.011078
# 4225            0.790640    0.722492    0.614586     0.589352  0.014321
# 4770            0.773176    0.747692    0.558938     0.643214 -0.040618
# Total Bags      1.000000    0.929040    0.709648     0.633930  0.222446
# Small Bags      0.929040    1.000000    0.526174     0.599928  0.202987
# Large Bags      0.709648    0.526174    1.000000     0.469564  0.193857
# XLarge Bags     0.633930    0.599928    0.469564     1.000000  0.168146
# year            0.222446    0.202987    0.193857     0.168146  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df_avocado)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df_avocado['region']= label_encoder.fit_transform(df_avocado['region']) 
print(df_avocado.head())
# Out:
#          Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0  2015-12-27      0.845868     11.070344  6.944801  10.905146  3.895080
# 1  2015-12-20      0.854415     10.912867  6.515127  10.706381  4.083115
# 2  2015-12-13      0.657520     11.680313  6.679222  11.600485  4.879007
# 3  2015-12-06      0.732368     11.277116  7.032624  11.184108  4.298373
# 4  2015-11-29      0.824175     10.840377  6.848515  10.688288  4.340944
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0    9.070833    9.060055    4.545951          0.0  conventional  2015       0
# 1    9.159737    9.149429    4.589955          0.0  conventional  2015       0
# 2    9.005325    8.992584    4.645736          0.0  conventional  2015       0
# 3    8.667708    8.644425    4.903495          0.0  conventional  2015       0
# 4    8.729874    8.697389    5.291746          0.0  conventional  2015       0

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df_avocado['type']= label_encoder.fit_transform(df_avocado['type']) 
print(df_avocado.head())
# Out:
#          Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0  2015-12-27      0.845868     11.070344  6.944801  10.905146  3.895080
# 1  2015-12-20      0.854415     10.912867  6.515127  10.706381  4.083115
# 2  2015-12-13      0.657520     11.680313  6.679222  11.600485  4.879007
# 3  2015-12-06      0.732368     11.277116  7.032624  11.184108  4.298373
# 4  2015-11-29      0.824175     10.840377  6.848515  10.688288  4.340944
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0    9.070833    9.060055    4.545951          0.0     0  2015       0
# 1    9.159737    9.149429    4.589955          0.0     0  2015       0
# 2    9.005325    8.992584    4.645736          0.0     0  2015       0
# 3    8.667708    8.644425    4.903495          0.0     0  2015       0
# 4    8.729874    8.697389    5.291746          0.0     0  2015       0

# %%
df_avocado.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# dtype: object

# %%
df_avocado=df_avocado.drop(columns=['year'])

# %%
df_avocado=df_avocado.drop(columns=['type'])

# %%
df_avocado=df_avocado.drop(columns=["Date"])

# %%
#df_avocado['year'] = df_avocado['year'].astype(float)
#df_with_region=df_avocado
df_avocado.shape
# Out:
# (18249, 10)

# %%
#check outliars
#from scipy.stats import zscore
#z_score=np.abs(zscore(df_avocado))
#z_score
#df = pd.DataFrame(np.random.randn(5,8), columns=["Total Volume", "4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags"])

#from scipy.stats import zscore
#z_score=abs(zscore(df_avocado))
#df_avocado_final= df_avocado.loc[(z_score<3).all(axis=1)]
#print(df_avocado_final.shape)

from scipy.stats import zscore
z_score=abs(zscore(df_avocado))
df_avocado_final= df_avocado.loc[(z_score<3).all(axis=1)]
print(df_avocado_final.shape)
# Out:
# (17928, 10)

# %%
#saperate input and target variabke
import numpy as np
df_x=df_avocado_final.drop(columns=["AveragePrice"])
y=df_avocado_final["AveragePrice"]
print(df_x.shape)
print(y.shape)
# Out:
# (17928, 9)
# (17928,)

# %%
#calculating r2 score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,Y_test=train_test_split(df_x,y,random_state=55,test_size=0.20)
model=[DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
from sklearn.decomposition import PCA
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,Y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.33)
    for i in model:
        i.fit(x_train,y_train)
        pre=i.predict(x_test)
        r2_sc=r2_score(Y_test,pre)
        print("max r2 score corrospond to random state",r_state,"is",r2_sc)
        if r2_sc>max_r_score:
            max_r_score=r2_sc
            final_r_state=r_state
            final_model=i
            print()
            print()
            print()
            print()
            print("max r2 score corrospond to random state",final_r_state,"is",max_r_score,"and model is",final_model)
# Out:
# max r2 score corrospond to random state 42 is 0.6188928511381491
#
#
#
#
# max r2 score corrospond to random state 42 is 0.6188928511381491 and model is DecisionTreeRegressor()
# max r2 score corrospond to random state 42 is 0.8143613294582623
#
#
#
#
# max r2 score corrospond to random state 42 is 0.8143613294582623 and model is KNeighborsRegressor()
# max r2 score corrospond to random state 42 is 0.46825311363854116
# max r2 score corrospond to random state 42 is 0.4442445967566717
# max r2 score corrospond to random state 42 is 0.6433974664603563
# max r2 score corrospond to random state 43 is 0.6454835301353044
# max r2 score corrospond to random state 43 is 0.8033860987345095
# max r2 score corrospond to random state 43 is 0.4475766497477679
# max r2 score corrospond to random state 43 is 0.43904998183454913
# max r2 score corrospond to random state 43 is 0.6425181317474793
# max r2 score corrospond to random state 44 is 0.6440039563288878
# max r2 score corrospond to random state 44 is 0.8115682803546176
# max r2 score corrospond to random state 44 is 0.45858905523663906
# max r2 score corrospond to random state 44 is 0.4483514633921829
# max r2 score corrospond to random state 44 is 0.6481428725751035
# max r2 score corrospond to random state 45 is 0.6403288368948383
# max r2 score corrospond to random state 45 is 0.8094220585397082
# max r2 score corrospond to random state 45 is 0.44152950469738583
# max r2 score corrospond to random state 45 is 0.4412115845862845
# max r2 score corrospond to random state 45 is 0.6431735331074144
# max r2 score corrospond to random state 46 is 0.645098596003559
# max r2 score corrospond to random state 46 is 0.8055842729478958
# max r2 score corrospond to random state 46 is 0.47035237611003766
# max r2 score corrospond to random state 46 is 0.44727592172837305
# max r2 score corrospond to random state 46 is 0.6472890297177725
# max r2 score corrospond to random state 47 is 0.6329767762470682
# max r2 score corrospond to random state 47 is 0.8072712976599965
# max r2 score corrospond to random state 47 is 0.44992337931726245
# max r2 score corrospond to random state 47 is 0.4392748827633556
# max r2 score corrospond to random state 47 is 0.6405598309075098
# max r2 score corrospond to random state 48 is 0.6338920111553044
# max r2 score corrospond to random state 48 is 0.8020132974889427
# max r2 score corrospond to random state 48 is 0.4470399624694614
# max r2 score corrospond to random state 48 is 0.44271352778965556
# max r2 score corrospond to random state 48 is 0.6470282306343298
# max r2 score corrospond to random state 49 is 0.6350163002523095
# max r2 score corrospond to random state 49 is 0.8098767644082069
# max r2 score corrospond to random state 49 is 0.4577780170903123
# max r2 score corrospond to random state 49 is 0.4391159160738022
# max r2 score corrospond to random state 49 is 0.6477813390198
# max r2 score corrospond to random state 50 is 0.6307264838808561
# max r2 score corrospond to random state 50 is 0.7997729315538546
# max r2 score corrospond to random state 50 is 0.46107569529543857
# max r2 score corrospond to random state 50 is 0.4346132697471353
# max r2 score corrospond to random state 50 is 0.6413575910323988
# max r2 score corrospond to random state 51 is 0.6471934714604479
# max r2 score corrospond to random state 51 is 0.8067872294117822
# max r2 score corrospond to random state 51 is 0.48033404272617364
# max r2 score corrospond to random state 51 is 0.4468763815506761
# max r2 score corrospond to random state 51 is 0.6426458835624571
# max r2 score corrospond to random state 52 is 0.6673566571704512
# max r2 score corrospond to random state 52 is 0.8131269305002957
# max r2 score corrospond to random state 52 is 0.47080474118991245
# max r2 score corrospond to random state 52 is 0.4438808102686995
# max r2 score corrospond to random state 52 is 0.6461892880490667
# max r2 score corrospond to random state 53 is 0.6468885603304484
# max r2 score corrospond to random state 53 is 0.8082928525844488
# max r2 score corrospond to random state 53 is 0.4728820154408685
# max r2 score corrospond to random state 53 is 0.4544332205516477
# max r2 score corrospond to random state 53 is 0.653361826347812
# max r2 score corrospond to random state 54 is 0.6363680645992105
# max r2 score corrospond to random state 54 is 0.8059198589975975
# max r2 score corrospond to random state 54 is 0.467111518410279
# max r2 score corrospond to random state 54 is 0.4485674431249802
# max r2 score corrospond to random state 54 is 0.6482912169862651
# max r2 score corrospond to random state 55 is 0.6135350251754148
# max r2 score corrospond to random state 55 is 0.7936870531171096
# max r2 score corrospond to random state 55 is 0.47645824447024165
# max r2 score corrospond to random state 55 is 0.4369199053082907
# max r2 score corrospond to random state 55 is 0.6360201716861785
# max r2 score corrospond to random state 56 is 0.6308976717677426
# max r2 score corrospond to random state 56 is 0.8049523641743171
# max r2 score corrospond to random state 56 is 0.4501652770834621
# max r2 score corrospond to random state 56 is 0.4467006490678902
# max r2 score corrospond to random state 56 is 0.6478919113733188
# max r2 score corrospond to random state 57 is 0.6327957344004465
# max r2 score corrospond to random state 57 is 0.8053431053079778
# max r2 score corrospond to random state 57 is 0.4626944979751513
# max r2 score corrospond to random state 57 is 0.4358633531705359
# max r2 score corrospond to random state 57 is 0.6315334286560234
# max r2 score corrospond to random state 58 is 0.6086156493752868
# max r2 score corrospond to random state 58 is 0.8118201287192803
# max r2 score corrospond to random state 58 is 0.4683102499511905
# max r2 score corrospond to random state 58 is 0.45612844485174653
# max r2 score corrospond to random state 58 is 0.6546363356412332
# max r2 score corrospond to random state 59 is 0.6294993955992692
# max r2 score corrospond to random state 59 is 0.8094019578823146
# max r2 score corrospond to random state 59 is 0.43868774050452586
# max r2 score corrospond to random state 59 is 0.4371042193319117
# max r2 score corrospond to random state 59 is 0.6405634106113433
# max r2 score corrospond to random state 60 is 0.6323464453772625
# max r2 score corrospond to random state 60 is 0.8096487238351002
# max r2 score corrospond to random state 60 is 0.4534530647629663
# max r2 score corrospond to random state 60 is 0.4478531988293416
# max r2 score corrospond to random state 60 is 0.6515990727560199
# max r2 score corrospond to random state 61 is 0.6478964410917418
# max r2 score corrospond to random state 61 is 0.8066994297379468
# max r2 score corrospond to random state 61 is 0.4784000376506373
# max r2 score corrospond to random state 61 is 0.44667571738572476
# max r2 score corrospond to random state 61 is 0.6450969894240253
# max r2 score corrospond to random state 62 is 0.6584669839586468
# max r2 score corrospond to random state 62 is 0.8120565601644646
# max r2 score corrospond to random state 62 is 0.45734200992433593
# max r2 score corrospond to random state 62 is 0.44010575656927653
# max r2 score corrospond to random state 62 is 0.639718349536845
# max r2 score corrospond to random state 63 is 0.6358245086823178
# max r2 score corrospond to random state 63 is 0.8173726117320119
#
#
#
#
# max r2 score corrospond to random state 63 is 0.8173726117320119 and model is KNeighborsRegressor()
# max r2 score corrospond to random state 63 is 0.46504922129222326
# max r2 score corrospond to random state 63 is 0.44727127296784686
# max r2 score corrospond to random state 63 is 0.6511262521583101
# max r2 score corrospond to random state 64 is 0.6329856056021701
# max r2 score corrospond to random state 64 is 0.8057104896739741
# max r2 score corrospond to random state 64 is 0.46760366851471513
# max r2 score corrospond to random state 64 is 0.44007134485769994
# max r2 score corrospond to random state 64 is 0.6400117645708711
# max r2 score corrospond to random state 65 is 0.6585680315237247
# max r2 score corrospond to random state 65 is 0.8134842531815047
# max r2 score corrospond to random state 65 is 0.4749895302878304
# max r2 score corrospond to random state 65 is 0.4542457172033938
# max r2 score corrospond to random state 65 is 0.6621808144045385
# max r2 score corrospond to random state 66 is 0.6401388241388549
# max r2 score corrospond to random state 66 is 0.809923591028435
# max r2 score corrospond to random state 66 is 0.46081514249619604
# max r2 score corrospond to random state 66 is 0.44167349031255976
# max r2 score corrospond to random state 66 is 0.6412601938771642
# max r2 score corrospond to random state 67 is 0.627395273244322
# max r2 score corrospond to random state 67 is 0.8158417852731706
# max r2 score corrospond to random state 67 is 0.4784605980939449
# max r2 score corrospond to random state 67 is 0.4602437917663843
# max r2 score corrospond to random state 67 is 0.6625841903346521
# max r2 score corrospond to random state 68 is 0.6244903729064709
# max r2 score corrospond to random state 68 is 0.8117741066368469
# max r2 score corrospond to random state 68 is 0.4503041906700477
# max r2 score corrospond to random state 68 is 0.43594479674454056
# max r2 score corrospond to random state 68 is 0.6350700254962425
# max r2 score corrospond to random state 69 is 0.655771866329536
# max r2 score corrospond to random state 69 is 0.8014097473375789
# max r2 score corrospond to random state 69 is 0.45723729358703347
# max r2 score corrospond to random state 69 is 0.44201415347805717
# max r2 score corrospond to random state 69 is 0.6470353259744841
# max r2 score corrospond to random state 70 is 0.6197839917291811
# max r2 score corrospond to random state 70 is 0.8066095412679853
# max r2 score corrospond to random state 70 is 0.4552893014510867
# max r2 score corrospond to random state 70 is 0.43145138633541535
# max r2 score corrospond to random state 70 is 0.6370988745326203
# max r2 score corrospond to random state 71 is 0.6559467703583601
# max r2 score corrospond to random state 71 is 0.8126035674513616
# max r2 score corrospond to random state 71 is 0.4664901161305214
# max r2 score corrospond to random state 71 is 0.44988919834456964
# max r2 score corrospond to random state 71 is 0.6499730348027613
# max r2 score corrospond to random state 72 is 0.6282975923268402
# max r2 score corrospond to random state 72 is 0.8089420123152498
# max r2 score corrospond to random state 72 is 0.45966604826174917
# max r2 score corrospond to random state 72 is 0.44225852024313894
# max r2 score corrospond to random state 72 is 0.6521837147207046
# max r2 score corrospond to random state 73 is 0.638267365512986
# max r2 score corrospond to random state 73 is 0.7987559679410486
# max r2 score corrospond to random state 73 is 0.46762216816640567
# max r2 score corrospond to random state 73 is 0.4408472815180827
# max r2 score corrospond to random state 73 is 0.6399886354297808
# max r2 score corrospond to random state 74 is 0.6415298674479548
# max r2 score corrospond to random state 74 is 0.812228838637131
# max r2 score corrospond to random state 74 is 0.4647781280349905
# max r2 score corrospond to random state 74 is 0.4424497502103164
# max r2 score corrospond to random state 74 is 0.6426927218655796
# max r2 score corrospond to random state 75 is 0.633535967281362
# max r2 score corrospond to random state 75 is 0.8166083151767052
# max r2 score corrospond to random state 75 is 0.4682845207604738
# max r2 score corrospond to random state 75 is 0.4429812311474308
# max r2 score corrospond to random state 75 is 0.6439729586149352
# max r2 score corrospond to random state 76 is 0.6313220734462162
# max r2 score corrospond to random state 76 is 0.812544930501574
# max r2 score corrospond to random state 76 is 0.46146599445312053
# max r2 score corrospond to random state 76 is 0.43741608844353363
# max r2 score corrospond to random state 76 is 0.6387883312077829
# max r2 score corrospond to random state 77 is 0.6197963346117658
# max r2 score corrospond to random state 77 is 0.8127274834530847
# max r2 score corrospond to random state 77 is 0.46489153257051163
# max r2 score corrospond to random state 77 is 0.4380423817113278
# max r2 score corrospond to random state 77 is 0.6403036271410645
# max r2 score corrospond to random state 78 is 0.6481718723210366
# max r2 score corrospond to random state 78 is 0.8090928591429525
# max r2 score corrospond to random state 78 is 0.47727240528248416
# max r2 score corrospond to random state 78 is 0.45589326864640867
# max r2 score corrospond to random state 78 is 0.6509615884045632
# max r2 score corrospond to random state 79 is 0.6380413440996473
# max r2 score corrospond to random state 79 is 0.8141904091368225
# max r2 score corrospond to random state 79 is 0.47186173900990946
# max r2 score corrospond to random state 79 is 0.44948176681650864
# max r2 score corrospond to random state 79 is 0.652790896978253
# max r2 score corrospond to random state 80 is 0.6452675206366584
# max r2 score corrospond to random state 80 is 0.8113188724638938
# max r2 score corrospond to random state 80 is 0.4640384769868666
# max r2 score corrospond to random state 80 is 0.4418171996233624
# max r2 score corrospond to random state 80 is 0.6441754551614551
# max r2 score corrospond to random state 81 is 0.6559948561342319
# max r2 score corrospond to random state 81 is 0.8181283386838623
#
#
#
#
# max r2 score corrospond to random state 81 is 0.8181283386838623 and model is KNeighborsRegressor()
# max r2 score corrospond to random state 81 is 0.4693545861046654
# max r2 score corrospond to random state 81 is 0.4558127023361789
# max r2 score corrospond to random state 81 is 0.6597275933259474
# max r2 score corrospond to random state 82 is 0.6250298226562064
# max r2 score corrospond to random state 82 is 0.8110194832794564
# max r2 score corrospond to random state 82 is 0.44261958875891394
# max r2 score corrospond to random state 82 is 0.4374075561932709
# max r2 score corrospond to random state 82 is 0.6395977288621977
# max r2 score corrospond to random state 83 is 0.6421977993503762
# max r2 score corrospond to random state 83 is 0.8151354915369751
# max r2 score corrospond to random state 83 is 0.45258189391315495
# max r2 score corrospond to random state 83 is 0.43588259114613503
# max r2 score corrospond to random state 83 is 0.6426492574852405
# max r2 score corrospond to random state 84 is 0.6490111394599345
# max r2 score corrospond to random state 84 is 0.8064297467288033
# max r2 score corrospond to random state 84 is 0.46980896366307534
# max r2 score corrospond to random state 84 is 0.4506885809465472
# max r2 score corrospond to random state 84 is 0.6519179104874162
# max r2 score corrospond to random state 85 is 0.6526371382779428
# max r2 score corrospond to random state 85 is 0.8126944086218995
# max r2 score corrospond to random state 85 is 0.47041560740311106
# max r2 score corrospond to random state 85 is 0.4508273969512936
# max r2 score corrospond to random state 85 is 0.6488558806482798
# max r2 score corrospond to random state 86 is 0.6372298816262396
# max r2 score corrospond to random state 86 is 0.8080284684341977
# max r2 score corrospond to random state 86 is 0.4571557813042044
# max r2 score corrospond to random state 86 is 0.45724474370208046
# max r2 score corrospond to random state 86 is 0.6514683840964606
# max r2 score corrospond to random state 87 is 0.6364428429366598
# max r2 score corrospond to random state 87 is 0.8177425231077874
# max r2 score corrospond to random state 87 is 0.4668126785549187
# max r2 score corrospond to random state 87 is 0.4491916199316176
# max r2 score corrospond to random state 87 is 0.6556745909040045
# max r2 score corrospond to random state 88 is 0.6406856584485612
# max r2 score corrospond to random state 88 is 0.8139086996517728
# max r2 score corrospond to random state 88 is 0.4557485304962249
# max r2 score corrospond to random state 88 is 0.4299699200101996
# max r2 score corrospond to random state 88 is 0.6389974820004395
# max r2 score corrospond to random state 89 is 0.6380030426621627
# max r2 score corrospond to random state 89 is 0.8058664218037879
# max r2 score corrospond to random state 89 is 0.46023840275054906
# max r2 score corrospond to random state 89 is 0.4379543968298969
# max r2 score corrospond to random state 89 is 0.6419515626765451
# max r2 score corrospond to random state 90 is 0.6238734046023934
# max r2 score corrospond to random state 90 is 0.8123128308553147
# max r2 score corrospond to random state 90 is 0.4771581226526628
# max r2 score corrospond to random state 90 is 0.4557413734551681
# max r2 score corrospond to random state 90 is 0.655721880142399
# max r2 score corrospond to random state 91 is 0.6401175908116117
# max r2 score corrospond to random state 91 is 0.8109672518313793
# max r2 score corrospond to random state 91 is 0.4670461711274094
# max r2 score corrospond to random state 91 is 0.4491418161766684
# max r2 score corrospond to random state 91 is 0.6472139767009277
# max r2 score corrospond to random state 92 is 0.6453385846031188
# max r2 score corrospond to random state 92 is 0.8121773148589229
# max r2 score corrospond to random state 92 is 0.46649631749655907
# max r2 score corrospond to random state 92 is 0.452701070502905
# max r2 score corrospond to random state 92 is 0.6512573818521998
# max r2 score corrospond to random state 93 is 0.6510778036978788
# max r2 score corrospond to random state 93 is 0.8136741289718475
# max r2 score corrospond to random state 93 is 0.4686397454042348
# max r2 score corrospond to random state 93 is 0.4552922245592892
# max r2 score corrospond to random state 93 is 0.6545198868754678
# max r2 score corrospond to random state 94 is 0.6357638930808943
# max r2 score corrospond to random state 94 is 0.8119608728658552
# max r2 score corrospond to random state 94 is 0.45420938775233155
# max r2 score corrospond to random state 94 is 0.44629730057761074
# max r2 score corrospond to random state 94 is 0.6435445923819245
# max r2 score corrospond to random state 95 is 0.6433998613529679
# max r2 score corrospond to random state 95 is 0.8087262977635936
# max r2 score corrospond to random state 95 is 0.45864947594560546
# max r2 score corrospond to random state 95 is 0.4392908979774368
# max r2 score corrospond to random state 95 is 0.6403864191086459
# max r2 score corrospond to random state 96 is 0.6326602404020994
# max r2 score corrospond to random state 96 is 0.8054912613467355
# max r2 score corrospond to random state 96 is 0.4608277691448658
# max r2 score corrospond to random state 96 is 0.4373558291466523
# max r2 score corrospond to random state 96 is 0.6395303771730505
# max r2 score corrospond to random state 97 is 0.6070688441928456
# max r2 score corrospond to random state 97 is 0.8022560269866309
# max r2 score corrospond to random state 97 is 0.4482153700679514
# max r2 score corrospond to random state 97 is 0.43411319172992036
# max r2 score corrospond to random state 97 is 0.6325630954871555
# max r2 score corrospond to random state 98 is 0.6414104618732519
# max r2 score corrospond to random state 98 is 0.8142988191354438
# max r2 score corrospond to random state 98 is 0.4444112719845976
# max r2 score corrospond to random state 98 is 0.4397867120715002
# max r2 score corrospond to random state 98 is 0.6441770684218149
# max r2 score corrospond to random state 99 is 0.6335265938372728
# max r2 score corrospond to random state 99 is 0.7971415186898649
# max r2 score corrospond to random state 99 is 0.4542176774463045
# max r2 score corrospond to random state 99 is 0.43385698669304373
# max r2 score corrospond to random state 99 is 0.6336064135288538

# %%
#from sklearn.linear_model import LogisticRegression

#lr = LogisticRegression()

#print(lr.get_params().keys())

# %%
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsRegressor
import joblib
xc_train,xc_test,yc_train,Yc_test=train_test_split(df_x,y,random_state=81,test_size=0.33)
KN=KNeighborsRegressor()
parameters={'n_neighbors': range (1,30)}
gridsearch=GridSearchCV(KN,parameters)
gridsearch.fit(xc_train,yc_train)
gridsearch.best_params_
# Out:
# {'n_neighbors': 3}

# %%
KNN=KNeighborsRegressor(n_neighbors=3)
KNN.fit(xc_train,yc_train)
pred=KNN.predict(xc_test)
r2_sc=r2_score(Yc_test,pred)
print("R2 score is",r2_sc)
# Out:
# R2 score is 0.8182457660564951

# %%
# prediction with region
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
x_c=df_avocado_final.drop(columns=['region'])
y_c=df_avocado_final['region']
print(y_c.shape)
print(x_c.shape)
# Out:
# (17928,)
# (17928, 9)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(x_c)
x_c=pd.DataFrame(x_c,columns=x_c.columns)

# %%
model=[DecisionTreeClassifier(),KNeighborsClassifier()]
from sklearn.decomposition import PCA
max_acc_score=0
for r_state in range(42,100):
    xc_train,xc_test,yc_train,Yc_test=train_test_split(x_c,y_c,random_state=r_state,test_size=0.33)
    for i_c in model:
        i_c.fit(xc_train,yc_train)
        pre_c=i_c.predict(xc_test)
        ac_score=accuracy_score(Yc_test,pre_c.round())
        print("max accuracy score corrospond to random state",r_state,"is",ac_score)
        if ac_score>max_acc_score:           
            max_acc_score=ac_score
            final_state=r_state
            final_model=i_c
            print()
            print()
            print()
            print()
            print("max accuracy score corrospond to random state",final_state,"is",max_acc_score,"and model is",final_model)
# Out:
# max accuracy score corrospond to random state 42 is 0.016224438059827616
#
#
#
#
# max accuracy score corrospond to random state 42 is 0.016224438059827616 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 42 is 0.016224438059827616
# max accuracy score corrospond to random state 43 is 0.01825249281730607
#
#
#
#
# max accuracy score corrospond to random state 43 is 0.01825249281730607 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 43 is 0.01825249281730607
# max accuracy score corrospond to random state 44 is 0.016224438059827616
# max accuracy score corrospond to random state 44 is 0.016224438059827616
# max accuracy score corrospond to random state 45 is 0.015886428933581206
# max accuracy score corrospond to random state 45 is 0.015886428933581206
# max accuracy score corrospond to random state 46 is 0.01842149738042927
#
#
#
#
# max accuracy score corrospond to random state 46 is 0.01842149738042927 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 46 is 0.01842149738042927
# max accuracy score corrospond to random state 47 is 0.01757647456481325
# max accuracy score corrospond to random state 47 is 0.01757647456481325
# max accuracy score corrospond to random state 48 is 0.01791448369105966
# max accuracy score corrospond to random state 48 is 0.01791448369105966
# max accuracy score corrospond to random state 49 is 0.017745479127936455
# max accuracy score corrospond to random state 49 is 0.017745479127936455
# max accuracy score corrospond to random state 50 is 0.01605543349670441
# max accuracy score corrospond to random state 50 is 0.01605543349670441
# max accuracy score corrospond to random state 51 is 0.019773533885414907
#
#
#
#
# max accuracy score corrospond to random state 51 is 0.019773533885414907 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 51 is 0.019773533885414907
# max accuracy score corrospond to random state 52 is 0.01723846543856684
# max accuracy score corrospond to random state 52 is 0.01723846543856684
# max accuracy score corrospond to random state 53 is 0.01690045631232043
# max accuracy score corrospond to random state 53 is 0.01690045631232043
# max accuracy score corrospond to random state 54 is 0.019266520196045293
# max accuracy score corrospond to random state 54 is 0.019266520196045293
# max accuracy score corrospond to random state 55 is 0.01605543349670441
# max accuracy score corrospond to random state 55 is 0.01605543349670441
# max accuracy score corrospond to random state 56 is 0.01791448369105966
# max accuracy score corrospond to random state 56 is 0.01791448369105966
# max accuracy score corrospond to random state 57 is 0.01723846543856684
# max accuracy score corrospond to random state 57 is 0.01723846543856684
# max accuracy score corrospond to random state 58 is 0.01791448369105966
# max accuracy score corrospond to random state 58 is 0.01791448369105966
# max accuracy score corrospond to random state 59 is 0.01791448369105966
# max accuracy score corrospond to random state 59 is 0.01791448369105966
# max accuracy score corrospond to random state 60 is 0.018928511069798884
# max accuracy score corrospond to random state 60 is 0.018928511069798884
# max accuracy score corrospond to random state 61 is 0.018928511069798884
# max accuracy score corrospond to random state 61 is 0.018928511069798884
# max accuracy score corrospond to random state 62 is 0.01605543349670441
# max accuracy score corrospond to random state 62 is 0.01605543349670441
# max accuracy score corrospond to random state 63 is 0.016562447186074025
# max accuracy score corrospond to random state 63 is 0.016562447186074025
# max accuracy score corrospond to random state 64 is 0.018928511069798884
# max accuracy score corrospond to random state 64 is 0.018928511069798884
# max accuracy score corrospond to random state 65 is 0.01521041068108839
# max accuracy score corrospond to random state 65 is 0.01521041068108839
# max accuracy score corrospond to random state 66 is 0.01521041068108839
# max accuracy score corrospond to random state 66 is 0.01521041068108839
# max accuracy score corrospond to random state 67 is 0.01673145174919723
# max accuracy score corrospond to random state 67 is 0.01673145174919723
# max accuracy score corrospond to random state 68 is 0.019266520196045293
# max accuracy score corrospond to random state 68 is 0.019266520196045293
# max accuracy score corrospond to random state 69 is 0.01690045631232043
# max accuracy score corrospond to random state 69 is 0.01690045631232043
# max accuracy score corrospond to random state 70 is 0.017407470001690045
# max accuracy score corrospond to random state 70 is 0.017407470001690045
# max accuracy score corrospond to random state 71 is 0.01605543349670441
# max accuracy score corrospond to random state 71 is 0.01605543349670441
# max accuracy score corrospond to random state 72 is 0.018590501943552475
# max accuracy score corrospond to random state 72 is 0.018590501943552475
# max accuracy score corrospond to random state 73 is 0.015717424370458002
# max accuracy score corrospond to random state 73 is 0.015717424370458002
# max accuracy score corrospond to random state 74 is 0.01791448369105966
# max accuracy score corrospond to random state 74 is 0.01791448369105966
# max accuracy score corrospond to random state 75 is 0.01487240155484198
# max accuracy score corrospond to random state 75 is 0.01487240155484198
# max accuracy score corrospond to random state 76 is 0.01690045631232043
# max accuracy score corrospond to random state 76 is 0.01690045631232043
# max accuracy score corrospond to random state 77 is 0.014703396991718777
# max accuracy score corrospond to random state 77 is 0.014703396991718777
# max accuracy score corrospond to random state 78 is 0.018083488254182864
# max accuracy score corrospond to random state 78 is 0.018083488254182864
# max accuracy score corrospond to random state 79 is 0.016224438059827616
# max accuracy score corrospond to random state 79 is 0.016224438059827616
# max accuracy score corrospond to random state 80 is 0.015717424370458002
# max accuracy score corrospond to random state 80 is 0.015717424370458002
# max accuracy score corrospond to random state 81 is 0.020956565827277337
#
#
#
#
# max accuracy score corrospond to random state 81 is 0.020956565827277337 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 81 is 0.020956565827277337
# max accuracy score corrospond to random state 82 is 0.016562447186074025
# max accuracy score corrospond to random state 82 is 0.016562447186074025
# max accuracy score corrospond to random state 83 is 0.01757647456481325
# max accuracy score corrospond to random state 83 is 0.01757647456481325
# max accuracy score corrospond to random state 84 is 0.017745479127936455
# max accuracy score corrospond to random state 84 is 0.017745479127936455
# max accuracy score corrospond to random state 85 is 0.020956565827277337
# max accuracy score corrospond to random state 85 is 0.020956565827277337
# max accuracy score corrospond to random state 86 is 0.017745479127936455
# max accuracy score corrospond to random state 86 is 0.017745479127936455
# max accuracy score corrospond to random state 87 is 0.01875950650667568
# max accuracy score corrospond to random state 87 is 0.01875950650667568
# max accuracy score corrospond to random state 88 is 0.01791448369105966
# max accuracy score corrospond to random state 88 is 0.01791448369105966
# max accuracy score corrospond to random state 89 is 0.018083488254182864
# max accuracy score corrospond to random state 89 is 0.018083488254182864
# max accuracy score corrospond to random state 90 is 0.01723846543856684
# max accuracy score corrospond to random state 90 is 0.01723846543856684
# max accuracy score corrospond to random state 91 is 0.019604529322291703
# max accuracy score corrospond to random state 91 is 0.019604529322291703
# max accuracy score corrospond to random state 92 is 0.01875950650667568
# max accuracy score corrospond to random state 92 is 0.01875950650667568
# max accuracy score corrospond to random state 93 is 0.013858374176102755
# max accuracy score corrospond to random state 93 is 0.013858374176102755
# max accuracy score corrospond to random state 94 is 0.017745479127936455
# max accuracy score corrospond to random state 94 is 0.017745479127936455
# max accuracy score corrospond to random state 95 is 0.017407470001690045
# max accuracy score corrospond to random state 95 is 0.017407470001690045
# max accuracy score corrospond to random state 96 is 0.01791448369105966
# max accuracy score corrospond to random state 96 is 0.01791448369105966
# max accuracy score corrospond to random state 97 is 0.020280547574784518
# max accuracy score corrospond to random state 97 is 0.020280547574784518
# max accuracy score corrospond to random state 98 is 0.017745479127936455
# max accuracy score corrospond to random state 98 is 0.017745479127936455
# max accuracy score corrospond to random state 99 is 0.01791448369105966
# max accuracy score corrospond to random state 99 is 0.01791448369105966

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
xc_train,xc_test,yc_train,Yc_test=train_test_split(x_c,y_c,random_state=r_state,test_size=0.33)
KNC=KNeighborsClassifier()
parameters={'n_neighbors': range (1,30)}
gridsearch=GridSearchCV(KNC,parameters)
gridsearch.fit(xc_train,yc_train)
gridsearch.best_params_
# Out:
# {'n_neighbors': 1}

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
KNC=KNeighborsClassifier(n_neighbors=1)
KNC.fit(xc_train,yc_train)
pred=KNC.predict(xc_test)
acc_sc=accuracy_score(Yc_test,pred)
print("Accuracy score is",acc_sc)
# Out:
# Accuracy score is 0.8277843501774548

# %%
import joblib
joblib.dump(final_model,'Avocado.pkl')
# Out:
# ['Avocado.pkl']
