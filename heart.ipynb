# %%
import pandas as pd
import numpy as np
df=pd.read_csv("heart.csv")
df
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0    67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1    67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2    37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3    41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4    56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
# ..    ...  ...    ...    ...    ...    ...  ...    ...  ...  ...  ...   ...
# 297  45.0  1.0    1.0  110.0  264.0    0.0  0.0  132.0  0.0  1.2  2.0   0.0
# 298  68.0  1.0    4.0  144.0  193.0    1.0  0.0  141.0  0.0  3.4  2.0   2.0
# 299  57.0  1.0    4.0  130.0  131.0    0.0  0.0  115.0  1.0  1.2  2.0   1.0
# 300  57.0  0.0    2.0  130.0  236.0    0.0  2.0  174.0  0.0  0.0  2.0   1.0
# 301  38.0  1.0    3.0  138.0  175.0    0.0  0.0  173.0  0.0  0.0  1.0     ?
#
#      6.0  0
# 0    3.0  2
# 1    7.0  1
# 2    3.0  0
# 3    3.0  0
# 4    3.0  0
# ..   ... ..
# 297  7.0  1
# 298  7.0  2
# 299  7.0  3
# 300  3.0  1
# 301  3.0  0
#
# [302 rows x 14 columns]

# %%
df.columns=['Age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df
# Out:
#       Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 298  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 299  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 300  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 301  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      2.0  3.0  3.0    2
# 1      2.0  2.0  7.0    1
# 2      3.0  0.0  3.0    0
# 3      1.0  0.0  3.0    0
# 4      1.0  0.0  3.0    0
# ..     ...  ...  ...  ...
# 297    2.0  0.0  7.0    1
# 298    2.0  2.0  7.0    2
# 299    2.0  1.0  7.0    3
# 300    2.0  1.0  3.0    1
# 301    1.0    ?  3.0    0
#
# [302 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.dtypes
# Out:
# Age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
df.shape
# Out:
# (302, 14)

# %%
df.num.value_counts()
# Out:
# 0    163
# 1     55
# 2     36
# 3     35
# 4     13
# Name: num, dtype: int64

# %%
df.num.value_counts().plot(kind="bar", color=["salmon", "lightblue"])

# %%
pd.set_option("display.float", "{:.2f}".format)
df.describe()
df
# Out:
#       Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   67.00 1.00 4.00    160.00 286.00 0.00     2.00   108.00   1.00     1.50
# 1   67.00 1.00 4.00    120.00 229.00 0.00     2.00   129.00   1.00     2.60
# 2   37.00 1.00 3.00    130.00 250.00 0.00     0.00   187.00   0.00     3.50
# 3   41.00 0.00 2.00    130.00 204.00 0.00     2.00   172.00   0.00     1.40
# 4   56.00 1.00 2.00    120.00 236.00 0.00     0.00   178.00   0.00     0.80
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297 45.00 1.00 1.00    110.00 264.00 0.00     0.00   132.00   0.00     1.20
# 298 68.00 1.00 4.00    144.00 193.00 1.00     0.00   141.00   0.00     3.40
# 299 57.00 1.00 4.00    130.00 131.00 0.00     0.00   115.00   1.00     1.20
# 300 57.00 0.00 2.00    130.00 236.00 0.00     2.00   174.00   0.00     0.00
# 301 38.00 1.00 3.00    138.00 175.00 0.00     0.00   173.00   0.00     0.00
#
#      slope   ca thal  num
# 0     2.00  3.0  3.0    2
# 1     2.00  2.0  7.0    1
# 2     3.00  0.0  3.0    0
# 3     1.00  0.0  3.0    0
# 4     1.00  0.0  3.0    0
# ..     ...  ...  ...  ...
# 297   2.00  0.0  7.0    1
# 298   2.00  2.0  7.0    2
# 299   2.00  1.0  7.0    3
# 300   2.00  1.0  3.0    1
# 301   1.00    ?  3.0    0
#
# [302 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()

# %%
df.skew
# Out:
# <bound method DataFrame.skew of       Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   67.00 1.00 4.00    160.00 286.00 0.00     2.00   108.00   1.00     1.50
# 1   67.00 1.00 4.00    120.00 229.00 0.00     2.00   129.00   1.00     2.60
# 2   37.00 1.00 3.00    130.00 250.00 0.00     0.00   187.00   0.00     3.50
# 3   41.00 0.00 2.00    130.00 204.00 0.00     2.00   172.00   0.00     1.40
# 4   56.00 1.00 2.00    120.00 236.00 0.00     0.00   178.00   0.00     0.80
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297 45.00 1.00 1.00    110.00 264.00 0.00     0.00   132.00   0.00     1.20
# 298 68.00 1.00 4.00    144.00 193.00 1.00     0.00   141.00   0.00     3.40
# 299 57.00 1.00 4.00    130.00 131.00 0.00     0.00   115.00   1.00     1.20
# 300 57.00 0.00 2.00    130.00 236.00 0.00     2.00   174.00   0.00     0.00
# 301 38.00 1.00 3.00    138.00 175.00 0.00     0.00   173.00   0.00     0.00
#
#      slope   ca thal  num
# 0     2.00  3.0  3.0    2
# 1     2.00  2.0  7.0    1
# 2     3.00  0.0  3.0    0
# 3     1.00  0.0  3.0    0
# 4     1.00  0.0  3.0    0
# ..     ...  ...  ...  ...
# 297   2.00  0.0  7.0    1
# 298   2.00  2.0  7.0    2
# 299   2.00  1.0  7.0    3
# 300   2.00  1.0  3.0    1
# 301   1.00    ?  3.0    0
#
# [302 rows x 14 columns]>

# %%
skew=('sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope')
for col in skew:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
#checking corelation matrix
df.corr()
# Out:
#            Age   sex    cp  trestbps  chol   fbs  restecg  thalach  exang  \
# Age       1.00 -0.10  0.11      0.28  0.20  0.11     0.15    -0.39   0.09
# sex      -0.10  1.00  0.02     -0.06 -0.18  0.04     0.02    -0.05   0.15
# cp        0.11  0.02  1.00     -0.03  0.06 -0.02     0.08    -0.34   0.38
# trestbps  0.28 -0.06 -0.03      1.00  0.14  0.17     0.14    -0.04   0.06
# chol      0.20 -0.18  0.06      0.14  1.00  0.01     0.18    -0.00   0.07
# fbs       0.11  0.04 -0.02      0.17  0.01  1.00     0.06    -0.01   0.03
# restecg   0.15  0.02  0.08      0.14  0.18  0.06     1.00    -0.08   0.09
# thalach  -0.39 -0.05 -0.34     -0.04 -0.00 -0.01    -0.08     1.00  -0.38
# exang     0.09  0.15  0.38      0.06  0.07  0.03     0.09    -0.38   1.00
# oldpeak   0.23  0.10  0.21      0.17  0.04  0.01     0.11    -0.39   0.30
# slope     0.16  0.03  0.17      0.11 -0.01  0.04     0.13    -0.39   0.27
# num       0.23  0.23  0.41      0.16  0.07  0.07     0.19    -0.42   0.40
#
#           oldpeak  slope   num
# Age          0.23   0.16  0.23
# sex          0.10   0.03  0.23
# cp           0.21   0.17  0.41
# trestbps     0.17   0.11  0.16
# chol         0.04  -0.01  0.07
# fbs          0.01   0.04  0.07
# restecg      0.11   0.13  0.19
# thalach     -0.39  -0.39 -0.42
# exang        0.30   0.27  0.40
# oldpeak      1.00   0.59  0.49
# slope        0.59   1.00  0.39
# num          0.49   0.39  1.00

# %%
#ploting boxplot for each column to chek outliars
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,15))
# Out:
# Age             AxesSubplot(0.125,0.71587;0.133621x0.16413)
# sex          AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# cp            AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# trestbps     AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# chol         AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# fbs            AxesSubplot(0.125,0.518913;0.133621x0.16413)
# restecg     AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# thalach      AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# exang       AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# oldpeak     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# slope          AxesSubplot(0.125,0.321957;0.133621x0.16413)
# num         AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# dtype: object

# %%
df.dtypes
# Out:
# Age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
df.dropna(subset = ["trestbps"], inplace=True)
df.dropna(subset = ["chol"], inplace=True)
df.dropna(subset = ["ca"], inplace=True)

# %%
df[df!='?']
# Out:
# C:\Users\mayraj\Documents\isha\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#       Age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   67.00 1.00 4.00      5.08  5.66 0.00     2.00   108.00   0.69     0.92
# 1   67.00 1.00 4.00      4.80  5.44 0.00     2.00   129.00   0.69     1.28
# 2   37.00 1.00 3.00      4.88  5.53 0.00     0.00   187.00   0.00     1.50
# 3   41.00 0.00 2.00      4.88  5.32 0.00     2.00   172.00   0.00     0.88
# 4   56.00 1.00 2.00      4.80  5.47 0.00     0.00   178.00   0.00     0.59
# ..    ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 297 45.00 1.00 1.00      4.71  5.58 0.00     0.00   132.00   0.00     0.79
# 298 68.00 1.00 4.00      4.98  5.27 0.69     0.00   141.00   0.00     1.48
# 299 57.00 1.00 4.00      4.88  4.88 0.00     0.00   115.00   0.69     0.79
# 300 57.00 0.00 2.00      4.88  5.47 0.00     2.00   174.00   0.00     0.00
# 301 38.00 1.00 3.00      4.93  5.17 0.00     0.00   173.00   0.00     0.00
#
#      slope   ca thal  num
# 0     2.00  3.0  3.0    2
# 1     2.00  2.0  7.0    1
# 2     3.00  0.0  3.0    0
# 3     1.00  0.0  3.0    0
# 4     1.00  0.0  3.0    0
# ..     ...  ...  ...  ...
# 297   2.00  0.0  7.0    1
# 298   2.00  2.0  7.0    2
# 299   2.00  1.0  7.0    3
# 300   2.00  1.0  3.0    1
# 301   1.00  NaN  3.0    0
#
# [302 rows x 14 columns]

# %%
df
# Out:
#       Age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   67.00 1.00 4.00      5.08  5.66 0.00     2.00   108.00   0.69     0.92
# 1   67.00 1.00 4.00      4.80  5.44 0.00     2.00   129.00   0.69     1.28
# 2   37.00 1.00 3.00      4.88  5.53 0.00     0.00   187.00   0.00     1.50
# 3   41.00 0.00 2.00      4.88  5.32 0.00     2.00   172.00   0.00     0.88
# 4   56.00 1.00 2.00      4.80  5.47 0.00     0.00   178.00   0.00     0.59
# ..    ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 297 45.00 1.00 1.00      4.71  5.58 0.00     0.00   132.00   0.00     0.79
# 298 68.00 1.00 4.00      4.98  5.27 0.69     0.00   141.00   0.00     1.48
# 299 57.00 1.00 4.00      4.88  4.88 0.00     0.00   115.00   0.69     0.79
# 300 57.00 0.00 2.00      4.88  5.47 0.00     2.00   174.00   0.00     0.00
# 301 38.00 1.00 3.00      4.93  5.17 0.00     0.00   173.00   0.00     0.00
#
#      slope   ca thal  num
# 0     2.00  3.0  3.0    2
# 1     2.00  2.0  7.0    1
# 2     3.00  0.0  3.0    0
# 3     1.00  0.0  3.0    0
# 4     1.00  0.0  3.0    0
# ..     ...  ...  ...  ...
# 297   2.00  0.0  7.0    1
# 298   2.00  2.0  7.0    2
# 299   2.00  1.0  7.0    3
# 300   2.00  1.0  3.0    1
# 301   1.00    ?  3.0    0
#
# [302 rows x 14 columns]

# %%
df=df.drop(columns=["thal"])

# %%
df=df.drop(columns=["ca"])

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
df_final= df.loc[(z_score<3).all(axis=1)]
print(df_final.shape)
# Out:
# (297, 12)

# %%
df_final.shape
# Out:
# (297, 12)

# %%
model=[DecisionTreeClassifier(),KNeighborsClassifier()]
from sklearn.decomposition import PCA
max_acc_score=0
for r_state in range(42,100):
    xc_train,xc_test,yc_train,Yc_test=train_test_split(features,target,random_state=r_state,test_size=0.33)
    for i_c in model:
        i_c.fit(xc_train,yc_train)
        pre_c=i_c.predict(xc_test)
        ac_score=accuracy_score(Yc_test,pre_c.round())
        print("max accuracy score corrospond to random state",r_state,"is",ac_score)
        if ac_score>max_acc_score:          
            max_acc_score=ac_score
            final_state=r_state
            final_model=i_c
            print()
            print()
            print()
            print()
            print("max accuracy score corrospond to random state",final_state,"is",max_acc_score,"and model is",final_model)
# Out:
# max accuracy score corrospond to random state 42 is 0.45
#
#
#
#
# max accuracy score corrospond to random state 42 is 0.45 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 42 is 0.44
# max accuracy score corrospond to random state 43 is 0.48
#
#
#
#
# max accuracy score corrospond to random state 43 is 0.48 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 43 is 0.48
# max accuracy score corrospond to random state 44 is 0.51
#
#
#
#
# max accuracy score corrospond to random state 44 is 0.51 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 44 is 0.46
# max accuracy score corrospond to random state 45 is 0.45
# max accuracy score corrospond to random state 45 is 0.54
#
#
#
#
# max accuracy score corrospond to random state 45 is 0.54 and model is KNeighborsClassifier()
# max accuracy score corrospond to random state 46 is 0.5
# max accuracy score corrospond to random state 46 is 0.48
# max accuracy score corrospond to random state 47 is 0.41
# max accuracy score corrospond to random state 47 is 0.52
# max accuracy score corrospond to random state 48 is 0.36
# max accuracy score corrospond to random state 48 is 0.49
# max accuracy score corrospond to random state 49 is 0.55
#
#
#
#
# max accuracy score corrospond to random state 49 is 0.55 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 49 is 0.47
# max accuracy score corrospond to random state 50 is 0.42
# max accuracy score corrospond to random state 50 is 0.5
# max accuracy score corrospond to random state 51 is 0.48
# max accuracy score corrospond to random state 51 is 0.44
# max accuracy score corrospond to random state 52 is 0.44
# max accuracy score corrospond to random state 52 is 0.52
# max accuracy score corrospond to random state 53 is 0.45
# max accuracy score corrospond to random state 53 is 0.48
# max accuracy score corrospond to random state 54 is 0.52
# max accuracy score corrospond to random state 54 is 0.53
# max accuracy score corrospond to random state 55 is 0.43
# max accuracy score corrospond to random state 55 is 0.47
# max accuracy score corrospond to random state 56 is 0.49
# max accuracy score corrospond to random state 56 is 0.52
# max accuracy score corrospond to random state 57 is 0.5
# max accuracy score corrospond to random state 57 is 0.48
# max accuracy score corrospond to random state 58 is 0.55
# max accuracy score corrospond to random state 58 is 0.53
# max accuracy score corrospond to random state 59 is 0.41
# max accuracy score corrospond to random state 59 is 0.48
# max accuracy score corrospond to random state 60 is 0.42
# max accuracy score corrospond to random state 60 is 0.54
# max accuracy score corrospond to random state 61 is 0.51
# max accuracy score corrospond to random state 61 is 0.46
# max accuracy score corrospond to random state 62 is 0.37
# max accuracy score corrospond to random state 62 is 0.47
# max accuracy score corrospond to random state 63 is 0.44
# max accuracy score corrospond to random state 63 is 0.45
# max accuracy score corrospond to random state 64 is 0.44
# max accuracy score corrospond to random state 64 is 0.46
# max accuracy score corrospond to random state 65 is 0.49
# max accuracy score corrospond to random state 65 is 0.46
# max accuracy score corrospond to random state 66 is 0.41
# max accuracy score corrospond to random state 66 is 0.49
# max accuracy score corrospond to random state 67 is 0.53
# max accuracy score corrospond to random state 67 is 0.45
# max accuracy score corrospond to random state 68 is 0.36
# max accuracy score corrospond to random state 68 is 0.49
# max accuracy score corrospond to random state 69 is 0.51
# max accuracy score corrospond to random state 69 is 0.5
# max accuracy score corrospond to random state 70 is 0.47
# max accuracy score corrospond to random state 70 is 0.48
# max accuracy score corrospond to random state 71 is 0.4
# max accuracy score corrospond to random state 71 is 0.48
# max accuracy score corrospond to random state 72 is 0.53
# max accuracy score corrospond to random state 72 is 0.46
# max accuracy score corrospond to random state 73 is 0.53
# max accuracy score corrospond to random state 73 is 0.51
# max accuracy score corrospond to random state 74 is 0.41
# max accuracy score corrospond to random state 74 is 0.51
# max accuracy score corrospond to random state 75 is 0.41
# max accuracy score corrospond to random state 75 is 0.35
# max accuracy score corrospond to random state 76 is 0.48
# max accuracy score corrospond to random state 76 is 0.56
#
#
#
#
# max accuracy score corrospond to random state 76 is 0.56 and model is KNeighborsClassifier()
# max accuracy score corrospond to random state 77 is 0.43
# max accuracy score corrospond to random state 77 is 0.47
# max accuracy score corrospond to random state 78 is 0.39
# max accuracy score corrospond to random state 78 is 0.47
# max accuracy score corrospond to random state 79 is 0.5
# max accuracy score corrospond to random state 79 is 0.52
# max accuracy score corrospond to random state 80 is 0.47
# max accuracy score corrospond to random state 80 is 0.49
# max accuracy score corrospond to random state 81 is 0.43
# max accuracy score corrospond to random state 81 is 0.46
# max accuracy score corrospond to random state 82 is 0.51
# max accuracy score corrospond to random state 82 is 0.53
# max accuracy score corrospond to random state 83 is 0.48
# max accuracy score corrospond to random state 83 is 0.43
# max accuracy score corrospond to random state 84 is 0.47
# max accuracy score corrospond to random state 84 is 0.47
# max accuracy score corrospond to random state 85 is 0.46
# max accuracy score corrospond to random state 85 is 0.48
# max accuracy score corrospond to random state 86 is 0.45
# max accuracy score corrospond to random state 86 is 0.49
# max accuracy score corrospond to random state 87 is 0.47
# max accuracy score corrospond to random state 87 is 0.46
# max accuracy score corrospond to random state 88 is 0.46
# max accuracy score corrospond to random state 88 is 0.45
# max accuracy score corrospond to random state 89 is 0.53
# max accuracy score corrospond to random state 89 is 0.52
# max accuracy score corrospond to random state 90 is 0.46
# max accuracy score corrospond to random state 90 is 0.5
# max accuracy score corrospond to random state 91 is 0.48
# max accuracy score corrospond to random state 91 is 0.45
# max accuracy score corrospond to random state 92 is 0.55
# max accuracy score corrospond to random state 92 is 0.55
# max accuracy score corrospond to random state 93 is 0.4
# max accuracy score corrospond to random state 93 is 0.52
# max accuracy score corrospond to random state 94 is 0.44
# max accuracy score corrospond to random state 94 is 0.45
# max accuracy score corrospond to random state 95 is 0.59
#
#
#
#
# max accuracy score corrospond to random state 95 is 0.59 and model is DecisionTreeClassifier()
# max accuracy score corrospond to random state 95 is 0.57
# max accuracy score corrospond to random state 96 is 0.54
# max accuracy score corrospond to random state 96 is 0.51
# max accuracy score corrospond to random state 97 is 0.45
# max accuracy score corrospond to random state 97 is 0.49
# max accuracy score corrospond to random state 98 is 0.41
# max accuracy score corrospond to random state 98 is 0.4
# max accuracy score corrospond to random state 99 is 0.43
# max accuracy score corrospond to random state 99 is 0.43

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
xc_train,xc_test,yc_train,Yc_test=train_test_split(features,target,random_state=r_state,test_size=0.33)
KNC=KNeighborsClassifier()
parameters={'n_neighbors': range (1,30)}
gridsearch=GridSearchCV(KNC,parameters)
gridsearch.fit(xc_train,yc_train)
gridsearch.best_params_
# Out:
# {'n_neighbors': 23}

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
KNC=KNeighborsClassifier(n_neighbors=1)
KNC.fit(xc_train,yc_train)
pred=KNC.predict(xc_test)
acc_sc=accuracy_score(Yc_test,pred)
print("Accuracy score is",acc_sc)
# Out:
# Accuracy score is 0.35

# %%
import joblib
joblib.dump(final_model,'heart.pkl')
# Out:
# ['heart.pkl']
