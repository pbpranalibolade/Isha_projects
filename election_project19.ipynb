# %%
import pandas as pd
import numpy as np
df=pd.read_csv("ElectionData.csv")
df
# Out:
#        TimeElapsed                 time        territoryName  totalMandates  \
# 0                0  2019-10-06 20:10:02  Território Nacional              0
# 1                0  2019-10-06 20:10:02  Território Nacional              0
# 2                0  2019-10-06 20:10:02  Território Nacional              0
# 3                0  2019-10-06 20:10:02  Território Nacional              0
# 4                0  2019-10-06 20:10:02  Território Nacional              0
# ...            ...                  ...                  ...            ...
# 21638          265  2019-10-07 00:35:01                Viseu              8
# 21639          265  2019-10-07 00:35:01                Viseu              8
# 21640          265  2019-10-07 00:35:01                Viseu              8
# 21641          265  2019-10-07 00:35:01                Viseu              8
# 21642          265  2019-10-07 00:35:01                Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                    226         3092                 1081        9652
# 1                    226         3092                 1081        9652
# 2                    226         3092                 1081        9652
# 3                    226         3092                 1081        9652
# 4                    226         3092                 1081        9652
# ...                  ...          ...                  ...         ...
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                      2.50       8874  ...                 52.66
# 1                      2.50       8874  ...                 52.66
# 2                      2.50       8874  ...                 52.66
# 3                      2.50       8874  ...                 52.66
# 4                      2.50       8874  ...                 52.66
# ...                     ...        ...  ...                   ...
# 21638                  2.81       3700  ...                 51.28
# 21639                  2.81       3700  ...                 51.28
# 21640                  2.81       3700  ...                 51.28
# 21641                  2.81       3700  ...                 51.28
# 21642                  2.81       3700  ...                 51.28
#
#        pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                    813743           428546       PS         0       38.29
# 1                    813743           428546  PPD/PSD         0       33.28
# 2                    813743           428546     B.E.         0        6.81
# 3                    813743           428546   CDS-PP         0        4.90
# 4                    813743           428546  PCP-PEV         0        4.59
# ...                     ...              ...      ...       ...         ...
# 21638                371931           190712       NC         0        0.19
# 21639                371931           190712      PNR         0        0.18
# 21640                371931           190712      MPT         0        0.14
# 21641                371931           190712      PTP         0        0.13
# 21642                371931           190712      JPP         0        0.07
#
#        validVotesPercentage   Votes  Hondt  FinalMandates
# 0                     40.22  147993     94            106
# 1                     34.95  128624     81             77
# 2                      7.15   26307     16             19
# 3                      5.14   18923     12              5
# 4                      4.83   17757     11             12
# ...                     ...     ...    ...            ...
# 21638                  0.20     332      0              0
# 21639                  0.19     326      0              0
# 21640                  0.15     256      0              0
# 21641                  0.14     239      0              0
# 21642                  0.07     118      0              0
#
# [21643 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# FinalMandates                 int64
# dtype: object

# %%
#checking null values using heatmap
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.isnull())

# %%
df.describe(include='all')
# Out:
#          TimeElapsed                 time        territoryName  totalMandates  \
# count   21643.000000                21643                21643   21643.000000
# unique           NaN                   54                   21            NaN
# top              NaN  2019-10-06 21:40:02  Território Nacional            NaN
# freq             NaN                  403                 1134            NaN
# mean      133.146052                  NaN                  NaN      11.544795
# std        77.651193                  NaN                  NaN      31.314567
# min         0.000000                  NaN                  NaN       0.000000
# 25%        65.000000                  NaN                  NaN       1.000000
# 50%       135.000000                  NaN                  NaN       4.000000
# 75%       200.000000                  NaN                  NaN       9.000000
# max       265.000000                  NaN                  NaN     226.000000
#
#         availableMandates   numParishes  numParishesApproved     blankVotes  \
# count        21643.000000  21643.000000         21643.000000   21643.000000
# unique                NaN           NaN                  NaN            NaN
# top                   NaN           NaN                  NaN            NaN
# freq                  NaN           NaN                  NaN            NaN
# mean            11.499284    309.956013           261.090237    8875.066673
# std             31.738783    659.055911           583.377428   21484.874088
# min              0.000000     54.000000             3.000000      19.000000
# 25%              0.000000     75.000000            67.000000    1188.000000
# 50%              3.000000    147.000000           120.000000    2998.000000
# 75%              9.000000    242.000000           208.000000    6889.000000
# max            226.000000   3092.000000          3092.000000  129599.000000
#
#         blankVotesPercentage     nullVotes  ...  pre.votersPercentage  \
# count           21643.000000  21643.000000  ...          21643.000000
# unique                   NaN           NaN  ...                   NaN
# top                      NaN           NaN  ...                   NaN
# freq                     NaN           NaN  ...                   NaN
# mean                2.621629   6148.068752  ...             54.549372
# std                 0.795289  14735.469269  ...              4.964948
# min                 0.530000     39.000000  ...             40.870000
# 25%                 2.230000   1094.000000  ...             51.210000
# 50%                 2.640000   2232.000000  ...             56.260000
# 75%                 2.980000   4121.000000  ...             58.220000
# max                 5.460000  88539.000000  ...             62.580000
#
#         pre.subscribedVoters  pre.totalVoters  Party      Mandates  \
# count           2.164300e+04     2.164300e+04  21643  21643.000000
# unique                   NaN              NaN     21           NaN
# top                      NaN              NaN      L           NaN
# freq                     NaN              NaN   1127           NaN
# mean            6.378503e+05     3.594932e+05    NaN      0.565495
# std             1.544418e+06     8.763729e+05    NaN      4.421804
# min             6.383000e+03     3.215000e+03    NaN      0.000000
# 25%             1.289260e+05     6.964400e+04    NaN      0.000000
# 50%             2.284970e+05     1.102730e+05    NaN      0.000000
# 75%             3.933140e+05     2.276200e+05    NaN      0.000000
# max             9.439701e+06     5.380451e+06    NaN    106.000000
#
#           Percentage  validVotesPercentage         Votes         Hondt  \
# count   21643.000000          21643.000000  2.164300e+04  21643.000000
# unique           NaN                   NaN           NaN           NaN
# top              NaN                   NaN           NaN           NaN
# freq             NaN                   NaN           NaN           NaN
# mean        4.968484              5.207232  1.585209e+04      1.126138
# std        10.379967             10.881108  9.310605e+04      6.293552
# min         0.020000              0.020000  1.000000e+00      0.000000
# 25%         0.220000              0.230000  2.360000e+02      0.000000
# 50%         0.620000              0.650000  7.900000e+02      0.000000
# 75%         3.010000              3.160000  4.510000e+03      0.000000
# max        49.110000             51.420000  1.866407e+06     94.000000
#
#         FinalMandates
# count    21643.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         1.126138
# std          6.872644
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        106.000000
#
# [11 rows x 28 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt  
corr = df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))

# %%
df_covid.corr()
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# pre.blankVotes               0.195734       0.973357           0.383877
# pre.blankVotesPercentage     0.093739       0.034774          -0.008966
# pre.nullVotes                0.189902       0.969992           0.399074
# pre.nullVotesPercentage     -0.106054      -0.132143          -0.044174
# pre.votersPercentage         0.054761       0.151927           0.080524
# pre.subscribedVoters         0.193160       0.972976           0.391272
# pre.totalVoters              0.196667       0.975404           0.383089
# Mandates                     0.090190       0.336989           0.072320
# Percentage                   0.000767      -0.010171          -0.011083
# validVotesPercentage         0.000526      -0.010474          -0.011052
# Votes                        0.082417       0.395617           0.152348
# Hondt                       -0.001100       0.288420           0.291310
# FinalMandates               -0.001007       0.264117           0.266764
#
#                           numParishes  numParishesApproved  blankVotes  \
# TimeElapsed                 -0.001944             0.100432    0.192350
# totalMandates                0.765877             0.873415    0.969988
# availableMandates            0.745472             0.562719    0.390638
# numParishes                  1.000000             0.954092    0.861279
# numParishesApproved          0.954092             1.000000    0.951265
# blankVotes                   0.861279             0.951265    1.000000
# blankVotesPercentage         0.032013             0.035153    0.038503
# nullVotes                    0.870240             0.956142    0.998781
# nullVotesPercentage          0.013209            -0.037416   -0.150894
# votersPercentage             0.073855             0.081157    0.183970
# subscribedVoters             0.856855             0.946191    0.998297
# totalVoters                  0.850881             0.940941    0.997951
# pre.blankVotes               0.856779             0.947190    0.999657
# pre.blankVotesPercentage     0.036461             0.050378    0.072183
# pre.nullVotes                0.864837             0.951899    0.997490
# pre.nullVotesPercentage     -0.058017            -0.073301   -0.150275
# pre.votersPercentage         0.026407             0.042180    0.161642
# pre.subscribedVoters         0.860782             0.949110    0.998487
# pre.totalVoters              0.853779             0.943147    0.998178
# Mandates                     0.257365             0.293795    0.326630
# Percentage                  -0.010770            -0.009840   -0.011883
# validVotesPercentage        -0.010624            -0.009767   -0.012002
# Votes                        0.343593             0.380311    0.404003
# Hondt                        0.359283             0.340901    0.322780
# FinalMandates                0.329009             0.312177    0.295583
#
#                           blankVotesPercentage  nullVotes  \
# TimeElapsed                           0.034343   0.185784
# totalMandates                        -0.003149   0.967294
# availableMandates                    -0.002806   0.407366
# numParishes                           0.032013   0.870240
# numParishesApproved                   0.035153   0.956142
# blankVotes                            0.038503   0.998781
# blankVotesPercentage                  1.000000   0.006615
# nullVotes                             0.006615   1.000000
# nullVotesPercentage                   0.094047  -0.136296
# votersPercentage                     -0.190778   0.181411
# subscribedVoters                      0.001598   0.998988
# totalVoters                          -0.002062   0.998405
# pre.blankVotes                        0.030061   0.998883
# pre.blankVotesPercentage              0.959142   0.041317
# pre.nullVotes                        -0.006067   0.999298
# pre.nullVotesPercentage              -0.307544  -0.125639
# pre.votersPercentage                 -0.105314   0.154965
# pre.subscribedVoters                  0.002821   0.999296
# pre.totalVoters                      -0.000069   0.998706
# Mandates                             -0.000926   0.325711
# Percentage                           -0.006258  -0.011602
# validVotesPercentage                 -0.002076  -0.011820
# Votes                                -0.001486   0.404195
# Hondt                                -0.001305   0.326144
# FinalMandates                        -0.001195   0.298663
#
#                           nullVotesPercentage  votersPercentage  ...  \
# TimeElapsed                         -0.225021          0.029698  ...
# totalMandates                       -0.165132          0.171317  ...
# availableMandates                    0.029915          0.112293  ...
# numParishes                          0.013209          0.073855  ...
# numParishesApproved                 -0.037416          0.081157  ...
# blankVotes                          -0.150894          0.183970  ...
# blankVotesPercentage                 0.094047         -0.190778  ...
# nullVotes                           -0.136296          0.181411  ...
# nullVotesPercentage                  1.000000         -0.108855  ...
# votersPercentage                    -0.108855          1.000000  ...
# subscribedVoters                    -0.157263          0.173603  ...
# totalVoters                         -0.161816          0.190476  ...
# pre.blankVotes                      -0.152234          0.181595  ...
# pre.blankVotesPercentage             0.100924         -0.144312  ...
# pre.nullVotes                       -0.141809          0.170285  ...
# pre.nullVotesPercentage              0.497749         -0.278275  ...
# pre.votersPercentage                -0.233688          0.909825  ...
# pre.subscribedVoters                -0.153891          0.172542  ...
# pre.totalVoters                     -0.159566          0.186834  ...
# Mandates                            -0.056254          0.056553  ...
# Percentage                           0.003301         -0.019836  ...
# validVotesPercentage                 0.005441         -0.020966  ...
# Votes                               -0.066526          0.076377  ...
# Hondt                               -0.032388          0.066665  ...
# FinalMandates                       -0.029659          0.061048  ...
#
#                           pre.nullVotesPercentage  pre.votersPercentage  \
# TimeElapsed                             -0.106054              0.054761
# totalMandates                           -0.132143              0.151927
# availableMandates                       -0.044174              0.080524
# numParishes                             -0.058017              0.026407
# numParishesApproved                     -0.073301              0.042180
# blankVotes                              -0.150275              0.161642
# blankVotesPercentage                    -0.307544             -0.105314
# nullVotes                               -0.125639              0.154965
# nullVotesPercentage                      0.497749             -0.233688
# votersPercentage                        -0.278275              0.909825
# subscribedVoters                        -0.133139              0.152401
# totalVoters                             -0.139684              0.167300
# pre.blankVotes                          -0.144753              0.160625
# pre.blankVotesPercentage                -0.215877             -0.106425
# pre.nullVotes                           -0.109795              0.145249
# pre.nullVotesPercentage                  1.000000             -0.499374
# pre.votersPercentage                    -0.499374              1.000000
# pre.subscribedVoters                    -0.131705              0.150632
# pre.totalVoters                         -0.139431              0.165287
# Mandates                                -0.044964              0.050533
# Percentage                               0.000391             -0.012054
# validVotesPercentage                     0.000158             -0.013078
# Votes                                   -0.057086              0.067619
# Hondt                                   -0.042245              0.055092
# FinalMandates                           -0.038686              0.050450
#
#                           pre.subscribedVoters  pre.totalVoters  Mandates  \
# TimeElapsed                           0.193160         0.196667  0.090190
# totalMandates                         0.972976         0.975404  0.336989
# availableMandates                     0.391272         0.383089  0.072320
# numParishes                           0.860782         0.853779  0.257365
# numParishesApproved                   0.949110         0.943147  0.293795
# blankVotes                            0.998487         0.998178  0.326630
# blankVotesPercentage                  0.002821        -0.000069 -0.000926
# nullVotes                             0.999296         0.998706  0.325711
# nullVotesPercentage                  -0.153891        -0.159566 -0.056254
# votersPercentage                      0.172542         0.186834  0.056553
# subscribedVoters                      0.999954         0.999841  0.328197
# totalVoters                           0.999515         0.999952  0.328836
# pre.blankVotes                        0.999203         0.999085  0.327807
# pre.blankVotesPercentage              0.037737         0.035404  0.011932
# pre.nullVotes                         0.999499         0.998879  0.326680
# pre.nullVotesPercentage              -0.131705        -0.139431 -0.044964
# pre.votersPercentage                  0.150632         0.165287  0.050533
# pre.subscribedVoters                  1.000000         0.999725  0.327703
# pre.totalVoters                       0.999725         1.000000  0.328527
# Mandates                              0.327703         0.328527  1.000000
# Percentage                           -0.011279        -0.011453  0.312402
# validVotesPercentage                 -0.011540        -0.011737  0.311762
# Votes                                 0.404765         0.404976  0.972310
# Hondt                                 0.323704         0.322329  0.791960
# FinalMandates                         0.296428         0.295169  0.814370
#
#                           Percentage  validVotesPercentage     Votes  \
# TimeElapsed                 0.000767              0.000526  0.082417
# totalMandates              -0.010171             -0.010474  0.395617
# availableMandates          -0.011083             -0.011052  0.152348
# numParishes                -0.010770             -0.010624  0.343593
# numParishesApproved        -0.009840             -0.009767  0.380311
# blankVotes                 -0.011883             -0.012002  0.404003
# blankVotesPercentage       -0.006258             -0.002076 -0.001486
# nullVotes                  -0.011602             -0.011820  0.404195
# nullVotesPercentage         0.003301              0.005441 -0.066526
# votersPercentage           -0.019836             -0.020966  0.076377
# subscribedVoters           -0.011276             -0.011548  0.404861
# totalVoters                -0.011560             -0.011856  0.404996
# pre.blankVotes             -0.011719             -0.011872  0.404458
# pre.blankVotesPercentage   -0.008944             -0.004922  0.013206
# pre.nullVotes              -0.011332             -0.011607  0.404354
# pre.nullVotesPercentage     0.000391              0.000158 -0.057086
# pre.votersPercentage       -0.012054             -0.013078  0.067619
# pre.subscribedVoters       -0.011279             -0.011540  0.404765
# pre.totalVoters            -0.011453             -0.011737  0.404976
# Mandates                    0.312402              0.311762  0.972310
# Percentage                  1.000000              0.999944  0.327706
# validVotesPercentage        0.999944              1.000000  0.327054
# Votes                       0.327706              0.327054  1.000000
# Hondt                       0.401192              0.400857  0.872658
# FinalMandates               0.383086              0.382744  0.882502
#
#                              Hondt  FinalMandates
# TimeElapsed              -0.001100      -0.001007
# totalMandates             0.288420       0.264117
# availableMandates         0.291310       0.266764
# numParishes               0.359283       0.329009
# numParishesApproved       0.340901       0.312177
# blankVotes                0.322780       0.295583
# blankVotesPercentage     -0.001305      -0.001195
# nullVotes                 0.326144       0.298663
# nullVotesPercentage      -0.032388      -0.029659
# votersPercentage          0.066665       0.061048
# subscribedVoters          0.322750       0.295555
# totalVoters               0.321587       0.294490
# pre.blankVotes            0.321997       0.294866
# pre.blankVotesPercentage  0.006242       0.005716
# pre.nullVotes             0.324854       0.297482
# pre.nullVotesPercentage  -0.042245      -0.038686
# pre.votersPercentage      0.055092       0.050450
# pre.subscribedVoters      0.323704       0.296428
# pre.totalVoters           0.322329       0.295169
# Mandates                  0.791960       0.814370
# Percentage                0.401192       0.383086
# validVotesPercentage      0.400857       0.382744
# Votes                     0.872658       0.882502
# Hondt                     1.000000       0.994480
# FinalMandates             0.994480       1.000000
#
# [25 rows x 25 columns]

# %%
#ploting boxplot for each column to chek outliars
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,15))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e9cc2376b58a> in <module>
#       1 #ploting boxplot for each column to chek outliars
# ----> 2 df.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,15))
#
# ~\Documents\isha\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\Documents\isha\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Documents\isha\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     260         self._args_adjust()
#     261         self._compute_plot_data()
# --> 262         self._setup_subplots()
#     263         self._make_plot()
#     264         self._add_table()
#
# ~\Documents\isha\lib\site-packages\pandas\plotting\_matplotlib\core.py in _setup_subplots(self)
#     307     def _setup_subplots(self):
#     308         if self.subplots:
# --> 309             fig, axes = _subplots(
#     310                 naxes=self.nseries,
#     311                 sharex=self.sharex,
#
# ~\Documents\isha\lib\site-packages\pandas\plotting\_matplotlib\tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     223             fig.clear()
#     224
# --> 225     nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     226     nplots = nrows * ncols
#     227
#
# ~\Documents\isha\lib\site-packages\pandas\plotting\_matplotlib\tools.py in _get_layout(nplots, layout, layout_type)
#      62
#      63         if nrows * ncols < nplots:
# ---> 64             raise ValueError(
#      65                 f"Layout of {nrows}x{ncols} must be larger than required size {nplots}"
#      66             )
#
# ValueError: Layout of 4x5 must be larger than required size 25

# %%
df.skew
# Out:
# <bound method DataFrame.skew of        TimeElapsed                 time        territoryName  totalMandates  \
# 0                0  2019-10-06 20:10:02  Território Nacional              0
# 1                0  2019-10-06 20:10:02  Território Nacional              0
# 2                0  2019-10-06 20:10:02  Território Nacional              0
# 3                0  2019-10-06 20:10:02  Território Nacional              0
# 4                0  2019-10-06 20:10:02  Território Nacional              0
# ...            ...                  ...                  ...            ...
# 21638          265  2019-10-07 00:35:01                Viseu              8
# 21639          265  2019-10-07 00:35:01                Viseu              8
# 21640          265  2019-10-07 00:35:01                Viseu              8
# 21641          265  2019-10-07 00:35:01                Viseu              8
# 21642          265  2019-10-07 00:35:01                Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                    226         3092                 1081        9652
# 1                    226         3092                 1081        9652
# 2                    226         3092                 1081        9652
# 3                    226         3092                 1081        9652
# 4                    226         3092                 1081        9652
# ...                  ...          ...                  ...         ...
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                      2.50       8874  ...                 52.66
# 1                      2.50       8874  ...                 52.66
# 2                      2.50       8874  ...                 52.66
# 3                      2.50       8874  ...                 52.66
# 4                      2.50       8874  ...                 52.66
# ...                     ...        ...  ...                   ...
# 21638                  2.81       3700  ...                 51.28
# 21639                  2.81       3700  ...                 51.28
# 21640                  2.81       3700  ...                 51.28
# 21641                  2.81       3700  ...                 51.28
# 21642                  2.81       3700  ...                 51.28
#
#        pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                    813743           428546       PS         0       38.29
# 1                    813743           428546  PPD/PSD         0       33.28
# 2                    813743           428546     B.E.         0        6.81
# 3                    813743           428546   CDS-PP         0        4.90
# 4                    813743           428546  PCP-PEV         0        4.59
# ...                     ...              ...      ...       ...         ...
# 21638                371931           190712       NC         0        0.19
# 21639                371931           190712      PNR         0        0.18
# 21640                371931           190712      MPT         0        0.14
# 21641                371931           190712      PTP         0        0.13
# 21642                371931           190712      JPP         0        0.07
#
#        validVotesPercentage   Votes  Hondt  FinalMandates
# 0                     40.22  147993     94            106
# 1                     34.95  128624     81             77
# 2                      7.15   26307     16             19
# 3                      5.14   18923     12              5
# 4                      4.83   17757     11             12
# ...                     ...     ...    ...            ...
# 21638                  0.20     332      0              0
# 21639                  0.19     326      0              0
# 21640                  0.15     256      0              0
# 21641                  0.14     239      0              0
# 21642                  0.07     118      0              0
#
# [21643 rows x 28 columns]>

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column_name in df.columns:
    if df[column_name].dtype == object:
        df[column_name] = le.fit_transform(df[column_name])

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
df_final= df.loc[(z_score<3).all(axis=1)]
print(df_final.shape)
# Out:
# (18333, 28)

# %%
#saperate input and target variabke
import numpy as np
y=df_final["FinalMandates"]
df_x=df_final.drop(columns=["FinalMandates"])
print(df_x.shape)
print(y.shape)
# Out:
# (18333, 27)
# (18333,)

# %%
#calculating r2 score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,Y_test=train_test_split(df_x,y,random_state=55,test_size=0.20)
model=[DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
from sklearn.decomposition import PCA
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,Y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.33)
    for i in model:
        i.fit(x_train,y_train)
        pre=i.predict(x_test)
        r2_sc=r2_score(Y_test,pre)
        print("max r2 score corrospond to random state",r_state,"is",r2_sc)
        if r2_sc>max_r_score:
            max_r_score=r2_sc
            final_r_state=r_state
            final_model=i
            print()
            print()
            print()
            print()
            print("max r2 score corrospond to random state",final_r_state,"is",max_r_score,"and model is",final_model)
# Out:
# max r2 score corrospond to random state 42 is 0.9994623818430441
#
#
#
#
# max r2 score corrospond to random state 42 is 0.9994623818430441 and model is DecisionTreeRegressor()
# max r2 score corrospond to random state 42 is 0.8970532911850572
# max r2 score corrospond to random state 42 is 0.9854919327602624
# max r2 score corrospond to random state 42 is 0.9838256723572182
# max r2 score corrospond to random state 42 is 0.9965394628973286
# max r2 score corrospond to random state 43 is 0.999918943596855
#
#
#
#
# max r2 score corrospond to random state 43 is 0.999918943596855 and model is DecisionTreeRegressor()
# max r2 score corrospond to random state 43 is 0.9065581784544202
# max r2 score corrospond to random state 43 is 0.986290140443827
# max r2 score corrospond to random state 43 is 0.9872518011794771
# max r2 score corrospond to random state 43 is 0.996656422324008
# max r2 score corrospond to random state 44 is 0.9991898690079782
# max r2 score corrospond to random state 44 is 0.8689726538743725
# max r2 score corrospond to random state 44 is 0.9847361167308655
# max r2 score corrospond to random state 44 is 0.9864771782468592
# max r2 score corrospond to random state 44 is 0.9966514152841865
# max r2 score corrospond to random state 45 is 0.9998446008444903
# max r2 score corrospond to random state 45 is 0.8951086780141184
# max r2 score corrospond to random state 45 is 0.9897145647048363
# max r2 score corrospond to random state 45 is 0.987864136686478
# max r2 score corrospond to random state 45 is 0.9969031013590205
# max r2 score corrospond to random state 46 is 0.999473788354197
# max r2 score corrospond to random state 46 is 0.9045963251540661
# max r2 score corrospond to random state 46 is 0.9907590070441501
# max r2 score corrospond to random state 46 is 0.9876019470122398
# max r2 score corrospond to random state 46 is 0.9968731733658784
# max r2 score corrospond to random state 47 is 0.9994976922547016
# max r2 score corrospond to random state 47 is 0.9090966497508554
# max r2 score corrospond to random state 47 is 0.9895329037369719
# max r2 score corrospond to random state 47 is 0.9881750674063327
# max r2 score corrospond to random state 47 is 0.9971642039256773
# max r2 score corrospond to random state 48 is 0.999035772758226
# max r2 score corrospond to random state 48 is 0.8901622451788638
# max r2 score corrospond to random state 48 is 0.9756646082865983
# max r2 score corrospond to random state 48 is 0.9851226532438926
# max r2 score corrospond to random state 48 is 0.9954263933522466
# max r2 score corrospond to random state 49 is 0.9989708947860303
# max r2 score corrospond to random state 49 is 0.9041809490774771
# max r2 score corrospond to random state 49 is 0.9818847557396774
# max r2 score corrospond to random state 49 is 0.9840869429064862
# max r2 score corrospond to random state 49 is 0.9959582545236336
# max r2 score corrospond to random state 50 is 0.9989953268345332
# max r2 score corrospond to random state 50 is 0.8838138541559023
# max r2 score corrospond to random state 50 is 0.9878384519962695
# max r2 score corrospond to random state 50 is 0.9831978846713095
# max r2 score corrospond to random state 50 is 0.9969336780599889
# max r2 score corrospond to random state 51 is 0.9993921591603179
# max r2 score corrospond to random state 51 is 0.8760629894769331
# max r2 score corrospond to random state 51 is 0.9824189413899596
# max r2 score corrospond to random state 51 is 0.9847425664701027
# max r2 score corrospond to random state 51 is 0.9967949600692941
# max r2 score corrospond to random state 52 is 0.9992767983646729
# max r2 score corrospond to random state 52 is 0.8768201648903143
# max r2 score corrospond to random state 52 is 0.9832139797711232
# max r2 score corrospond to random state 52 is 0.9851594307768735
# max r2 score corrospond to random state 52 is 0.9958728013297529
# max r2 score corrospond to random state 53 is 0.9995821218377726
# max r2 score corrospond to random state 53 is 0.892742376344775
# max r2 score corrospond to random state 53 is 0.9877479376430801
# max r2 score corrospond to random state 53 is 0.9850377796003095
# max r2 score corrospond to random state 53 is 0.9967252610659073
# max r2 score corrospond to random state 54 is 0.9995844627532674
# max r2 score corrospond to random state 54 is 0.8861760373749997
# max r2 score corrospond to random state 54 is 0.9785512155814562
# max r2 score corrospond to random state 54 is 0.9826029363335338
# max r2 score corrospond to random state 54 is 0.996494838596669
# max r2 score corrospond to random state 55 is 0.9987937594897981
# max r2 score corrospond to random state 55 is 0.8523596079527508
# max r2 score corrospond to random state 55 is 0.9863181146086365
# max r2 score corrospond to random state 55 is 0.9841166317140398
# max r2 score corrospond to random state 55 is 0.9958237645383272
# max r2 score corrospond to random state 56 is 0.9991705042385451
# max r2 score corrospond to random state 56 is 0.9038083535186442
# max r2 score corrospond to random state 56 is 0.987488941213614
# max r2 score corrospond to random state 56 is 0.9855865294827649
# max r2 score corrospond to random state 56 is 0.9960149330760042
# max r2 score corrospond to random state 57 is 0.9996412912382969
# max r2 score corrospond to random state 57 is 0.8919318113617027
# max r2 score corrospond to random state 57 is 0.985109318997672
# max r2 score corrospond to random state 57 is 0.982662020738498
# max r2 score corrospond to random state 57 is 0.9960664580775231
# max r2 score corrospond to random state 58 is 0.9994842177816673
# max r2 score corrospond to random state 58 is 0.9061826530334012
# max r2 score corrospond to random state 58 is 0.9802484580926574
# max r2 score corrospond to random state 58 is 0.9872892219079036
# max r2 score corrospond to random state 58 is 0.9967076242598678
# max r2 score corrospond to random state 59 is 0.9999220668951752
#
#
#
#
# max r2 score corrospond to random state 59 is 0.9999220668951752 and model is DecisionTreeRegressor()
# max r2 score corrospond to random state 59 is 0.8654656398029021
# max r2 score corrospond to random state 59 is 0.9837239108420175
# max r2 score corrospond to random state 59 is 0.9846933955324896
# max r2 score corrospond to random state 59 is 0.9965356308106155
# max r2 score corrospond to random state 60 is 0.9994360229193894
# max r2 score corrospond to random state 60 is 0.9145945336384962
# max r2 score corrospond to random state 60 is 0.9901625750447285
# max r2 score corrospond to random state 60 is 0.9854769559588403
# max r2 score corrospond to random state 60 is 0.9967633681314633
# max r2 score corrospond to random state 61 is 0.9996936510664634
# max r2 score corrospond to random state 61 is 0.892535857604661
# max r2 score corrospond to random state 61 is 0.9838370469252249
# max r2 score corrospond to random state 61 is 0.9863864933329436
# max r2 score corrospond to random state 61 is 0.9962119336452593
# max r2 score corrospond to random state 62 is 1.0
#
#
#
#
# max r2 score corrospond to random state 62 is 1.0 and model is DecisionTreeRegressor()
# max r2 score corrospond to random state 62 is 0.8599735840164696
# max r2 score corrospond to random state 62 is 0.9802088353246872
# max r2 score corrospond to random state 62 is 0.9840150790677132
# max r2 score corrospond to random state 62 is 0.9964356485246645
# max r2 score corrospond to random state 63 is 0.9995449025759906
# max r2 score corrospond to random state 63 is 0.8799301296321819
# max r2 score corrospond to random state 63 is 0.9852560721318349
# max r2 score corrospond to random state 63 is 0.9844946450202909
# max r2 score corrospond to random state 63 is 0.9972103534308568
# max r2 score corrospond to random state 64 is 0.9993702978772064
# max r2 score corrospond to random state 64 is 0.8731052268907532
# max r2 score corrospond to random state 64 is 0.9857595741885372
# max r2 score corrospond to random state 64 is 0.9893933018436868
# max r2 score corrospond to random state 64 is 0.9971264708522151
# max r2 score corrospond to random state 65 is 0.9997657286100314
# max r2 score corrospond to random state 65 is 0.8906046317402831
# max r2 score corrospond to random state 65 is 0.9857686548521659
# max r2 score corrospond to random state 65 is 0.9849361065596093
# max r2 score corrospond to random state 65 is 0.9971550446765388
# max r2 score corrospond to random state 66 is 0.9996551179884828
# max r2 score corrospond to random state 66 is 0.8968871761965855
# max r2 score corrospond to random state 66 is 0.987680209240849
# max r2 score corrospond to random state 66 is 0.9874741561848416
# max r2 score corrospond to random state 66 is 0.9968634768641119
# max r2 score corrospond to random state 67 is 0.9996957378505483
# max r2 score corrospond to random state 67 is 0.8972780557236262
# max r2 score corrospond to random state 67 is 0.9888907300864875
# max r2 score corrospond to random state 67 is 0.9855210145962667
# max r2 score corrospond to random state 67 is 0.9974224341606978
# max r2 score corrospond to random state 68 is 0.9994017140324352
# max r2 score corrospond to random state 68 is 0.895862344485668
# max r2 score corrospond to random state 68 is 0.990138836739489
# max r2 score corrospond to random state 68 is 0.9837260391313442
# max r2 score corrospond to random state 68 is 0.9959293556812566
# max r2 score corrospond to random state 69 is 0.9993240114377584
# max r2 score corrospond to random state 69 is 0.8990691134696523
# max r2 score corrospond to random state 69 is 0.9791538664665214
# max r2 score corrospond to random state 69 is 0.9859266497678133
# max r2 score corrospond to random state 69 is 0.9958490956410578
# max r2 score corrospond to random state 70 is 0.9995619318804074
# max r2 score corrospond to random state 70 is 0.9028423319826233
# max r2 score corrospond to random state 70 is 0.9895620072000831
# max r2 score corrospond to random state 70 is 0.9863123710561593
# max r2 score corrospond to random state 70 is 0.9970536985253879
# max r2 score corrospond to random state 71 is 0.9997628697820378
# max r2 score corrospond to random state 71 is 0.8898261389984957
# max r2 score corrospond to random state 71 is 0.9852371527847794
# max r2 score corrospond to random state 71 is 0.980014928731725
# max r2 score corrospond to random state 71 is 0.9964727548919367
# max r2 score corrospond to random state 72 is 0.9994621950758784
# max r2 score corrospond to random state 72 is 0.897863161981827
# max r2 score corrospond to random state 72 is 0.9843142145907464
# max r2 score corrospond to random state 72 is 0.9851568050321527
# max r2 score corrospond to random state 72 is 0.996542196770053
# max r2 score corrospond to random state 73 is 0.9997626289537827
# max r2 score corrospond to random state 73 is 0.9145305986253222
# max r2 score corrospond to random state 73 is 0.9843376242499693
# max r2 score corrospond to random state 73 is 0.984995762851048
# max r2 score corrospond to random state 73 is 0.9961444711187494
# max r2 score corrospond to random state 74 is 0.9995471501907006
# max r2 score corrospond to random state 74 is 0.8998694729662062
# max r2 score corrospond to random state 74 is 0.9855881542905257
# max r2 score corrospond to random state 74 is 0.9859131702905422
# max r2 score corrospond to random state 74 is 0.9961814702766465
# max r2 score corrospond to random state 75 is 0.9989749095391881
# max r2 score corrospond to random state 75 is 0.8772950947785737
# max r2 score corrospond to random state 75 is 0.9881278737332704
# max r2 score corrospond to random state 75 is 0.9881767168337234
# max r2 score corrospond to random state 75 is 0.9962035525395309
# max r2 score corrospond to random state 76 is 0.9995835488095388
# max r2 score corrospond to random state 76 is 0.9032567226511066
# max r2 score corrospond to random state 76 is 0.9876396470872655
# max r2 score corrospond to random state 76 is 0.9848265268347414
# max r2 score corrospond to random state 76 is 0.9965231712123546
# max r2 score corrospond to random state 77 is 0.9997219468628046
# max r2 score corrospond to random state 77 is 0.8817412202194175
# max r2 score corrospond to random state 77 is 0.986237789025117
# max r2 score corrospond to random state 77 is 0.9835901047865444
# max r2 score corrospond to random state 77 is 0.9966207023363205
# max r2 score corrospond to random state 78 is 0.9996647003289949
# max r2 score corrospond to random state 78 is 0.8694638144816736
# max r2 score corrospond to random state 78 is 0.9889325438239505
# max r2 score corrospond to random state 78 is 0.9878769745295127
# max r2 score corrospond to random state 78 is 0.9973217857700454
# max r2 score corrospond to random state 79 is 0.9994045715045581
# max r2 score corrospond to random state 79 is 0.8652494278086815
# max r2 score corrospond to random state 79 is 0.9839351925316294
# max r2 score corrospond to random state 79 is 0.9847749324346122
# max r2 score corrospond to random state 79 is 0.9959612346317783
# max r2 score corrospond to random state 80 is 0.9999095657399149
# max r2 score corrospond to random state 80 is 0.8561154748340513
# max r2 score corrospond to random state 80 is 0.9851580729076129
# max r2 score corrospond to random state 80 is 0.9795101173945978
# max r2 score corrospond to random state 80 is 0.9956409303384256
# max r2 score corrospond to random state 81 is 0.999584052870304
# max r2 score corrospond to random state 81 is 0.8801406751068046
# max r2 score corrospond to random state 81 is 0.9823180161730674
# max r2 score corrospond to random state 81 is 0.9868301781881238
# max r2 score corrospond to random state 81 is 0.9966369235362039
# max r2 score corrospond to random state 82 is 0.9998277327592383
# max r2 score corrospond to random state 82 is 0.8840675923121771
# max r2 score corrospond to random state 82 is 0.9851912637921175
# max r2 score corrospond to random state 82 is 0.983872328900335
# max r2 score corrospond to random state 82 is 0.9960531489022164
# max r2 score corrospond to random state 83 is 0.9996208801373514
# max r2 score corrospond to random state 83 is 0.9006129697669518
# max r2 score corrospond to random state 83 is 0.9895292059763058
# max r2 score corrospond to random state 83 is 0.9862317213681903
# max r2 score corrospond to random state 83 is 0.997362148818208
# max r2 score corrospond to random state 84 is 0.9994255237131764
# max r2 score corrospond to random state 84 is 0.89720895799865
# max r2 score corrospond to random state 84 is 0.9888128580439423
# max r2 score corrospond to random state 84 is 0.9860489434954538

# %%
x_train,x_test,y_train,Y_test=train_test_split(df_x,y,random_state=91,test_size=0.20)
lreg=linear_model.LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),df_x,y,cv=10,scoring="r2").mean()

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("r2 score is",r2_score(Y_test,y_pred))
print("RMSE is",np.sqrt(mean_squared_error(Y_test,y_pred)))

# %%
import joblib
joblib.dump(lreg,'electionn.pkl')
